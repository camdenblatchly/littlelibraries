# %%
import pandas as pd
import glob
import os
import requests
import pprint

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
all_files = glob.glob(r'../data/*.csv')

# %%
# df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
all_data = []
for f in all_files:
    data = pd.read_csv(f)
    collection_name = os.path.splitext(os.path.basename(f))[0].capitalize()
    data['collection'] = collection_name
    all_data.append(data)

df = pd.concat(all_data, ignore_index = True)

# %%
df.head()
# Out:
#   item_type                                              title  \
# 0      book                                          Lifelines
# 1      book  Edith's Story: The True Story of a Young Girl'...
# 2      book   The Flight Attendant (Television Tie-In Edition)
# 3      book                               The Dalai Lama's Cat
# 4      book    Joey Pigza Swallowed the Key (Joey Pigza Books)
#
#           creators first_name  last_name     ean_isbn13  upc_isbn10  \
# 0        Leana Wen      Leana        Wen  9781250186232  1250186234
# 1    Edith Velmans      Edith    Velmans  9780553381108  0553381105
# 2  Chris Bohjalian      Chris  Bohjalian  9780593314005  059331400X
# 3     David Michie      David     Michie  9781401940584  1401940587
# 4      Jack Gantos       Jack     Gantos  9780064408332    64408337
#
#                                          description  \
# 0  From medical expert Leana Wen, MD,Lifelines is...
# 1  In 1940, while the Germans occupied Holland, f...
# 2  Now a limited series on HBO Max starring Kaley...
# 3  Oh! How adorable! I didn&#039;t know you had a...
# 4  Joey Pigza can&#039;t sit still. He can&#039;t...
#
#                           publisher publish_date  group tags  notes  price  \
# 0          Henry Holt &amp; Company   2021-07-27    NaN  NaN    NaN    NaN
# 1                            Bantam   2001-01-02    NaN  NaN    NaN    NaN
# 2  Knopf Doubleday Publishing Group   2020-12-08    NaN  NaN    NaN    NaN
# 3                 Hay House Visions   2012-10-01    NaN  NaN    NaN    NaN
# 4                     HarperCollins   2000-04-30    NaN  NaN    NaN    NaN
#
#    length  number_of_discs  number_of_players  age_group  ensemble  \
# 0   352.0              NaN                NaN        NaN       NaN
# 1   256.0              NaN                NaN        NaN       NaN
# 2   368.0              NaN                NaN        NaN       NaN
# 3   240.0              NaN                NaN        NaN       NaN
# 4   160.0              NaN                NaN        NaN       NaN
#
#    aspect_ratio  esrb  rating  review  review_date  status  began  completed  \
# 0           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 1           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 2           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 3           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 4           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
#
#         added  copies collection
# 0  2025-06-13       1    Norfolk
# 1  2025-06-13       1    Norfolk
# 2  2025-06-13       1    Norfolk
# 3  2025-06-13       1      Maple
# 4  2025-06-13       1      Maple

# %%
# Now loop through and call APIs for each entry
df['categories'] = None
for index, row in df.head(10).iterrows():
    
    print(f"-- Getting info for {row['title']}")
    book_isbn = row["ean_isbn13"]

    # Pull subjects data from Open Library API
    response = requests.get(f"https://openlibrary.org/isbn/{book_isbn}.json")
    open_lib_details = response.json()

    if 'subjects' in open_lib_details:
        subjects = open_lib_details['subjects']
        cleaned_subjects = ', '.join([subj.replace(',', '') for subj in subjects])
        df.at[index, 'subjects'] = cleaned_subjects

    if 'physical_format' in open_lib_details:
        df.at[index, 'physical_format'] = open_lib_details['physical_format']

    # Pull categories data from Google Books API
    response = requests.get(f"https://www.googleapis.com/books/v1/volumes?q=isbn:{book_isbn}")
    google_details = response.json()
    pprint.pprint(google_details)

    try:
        volume_info = google_details['items'][0]['volumeInfo']

        if 'categories' in volume_info:
            # Remove commas now, so I can accurately split categories on comma post-join
            cleaned_categories = ', '.join([cat.replace(',', '') for cat in volume_info['categories']])
            df.at[index, 'categories'] = cleaned_categories
            
    except:
        print(f"No Google details found for ISBN {book_isbn}")
        df.at[index, 'categories'] = None
# Out:
# -- Getting info for Lifelines
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=lIS-zQEACAAJ&hl=&source=gbs_api'},
#             'etag': '93qxjc5SwDY',
#             'id': 'lIS-zQEACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Here, in gripping detail, Wen lays '
#                                           'bare the lifesaving work of public '
#                                           'health and its innovative approach '
#                                           'to social ills, treating gun '
#                                           'violence as a contagious disease, '
#                                           'for example, and racism as a threat '
#                                           'to health.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/lIS-zQEACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Dr. Leana Wen'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Lifelines.html?hl=&id=lIS-zQEACAAJ',
#                            'categories': ['Social Science'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'From medical expert Leana Wen, MD, '
#                                           "Lifelines is an insider's account "
#                                           'of public health and its crucial '
#                                           'role—from opioid addiction to '
#                                           'global pandemic—and an inspiring '
#                                           'story of her journey from '
#                                           'struggling immigrant to being one '
#                                           'of Time’s 100 Most Influential '
#                                           'People. “Public health saved your '
#                                           'life today—you just don’t know it,” '
#                                           'is a phrase that Dr. Leana Wen '
#                                           'likes to use. You don’t know it '
#                                           'because good public health is '
#                                           'invisible. It becomes visible only '
#                                           'in its absence, when it is '
#                                           'underfunded and ignored, a bitter '
#                                           'truth laid bare as never before by '
#                                           'the devastation of COVID-19. Leana '
#                                           'Wen—emergency physician, former '
#                                           'Baltimore health commissioner, CNN '
#                                           'medical analyst, and Washington '
#                                           'Post contributing columnist—has '
#                                           'lived on the front lines of public '
#                                           'health, leading the fight against '
#                                           'the opioid epidemic, outbreaks of '
#                                           'infectious disease, maternal and '
#                                           'infant mortality, and COVID-19 '
#                                           'disinformation. Here, in gripping '
#                                           'detail, Wen lays bare the '
#                                           'lifesaving work of public health '
#                                           'and its innovative approach to '
#                                           'social ills, treating gun violence '
#                                           'as a contagious disease, for '
#                                           'example, and racism as a threat to '
#                                           'health. Wen also tells her own '
#                                           'uniquely American story: an '
#                                           'immigrant from China, she and her '
#                                           'family received food stamps and '
#                                           'were at times homeless despite her '
#                                           'parents working multiple jobs. That '
#                                           'child went on to attend college at '
#                                           'thirteen, become a Rhodes scholar, '
#                                           'and turn to public health as the '
#                                           'way to make a difference in the '
#                                           'country that had offered her such '
#                                           'possibilities. Ultimately, she '
#                                           'insists, it is public health that '
#                                           'ensures citizens are not robbed of '
#                                           'decades of life, and that where '
#                                           'children live does not determine '
#                                           'whether they live.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=lIS-zQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=lIS-zQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '1250186234',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9781250186232',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=lIS-zQEACAAJ&dq=isbn:9781250186232&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 352,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=lIS-zQEACAAJ&dq=isbn:9781250186232&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2021-07-27',
#                            'publisher': 'Metropolitan Books',
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': "A Doctor's Journey in the Fight for "
#                                        'Public Health',
#                            'title': 'Lifelines'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for Edith's Story: The True Story of a Young Girl's Courage and Survival During World War II
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=99f1cOQJufMC&hl=&source=gbs_api'},
#             'etag': 'ZthaIyyVJhw',
#             'id': '99f1cOQJufMC',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Edith&#39;s Story stands as a '
#                                           'profoundly important addition to '
#                                           'the literature of the Holocaust, '
#                                           'documenting one girl&#39;s grief, '
#                                           'loss, courage, and ultimate triumph '
#                                           'over devastating tyranny and '
#                                           'despair. For as Edith is h'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/99f1cOQJufMC',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Edith Velmans',
#                                        'Edith Velmans-Van Hessen'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Edith_s_Story.html?hl=&id=99f1cOQJufMC',
#                            'categories': ['Biography & Autobiography'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'A Dutch Jew who survived the '
#                                           'Holocaust by hiding out with her '
#                                           'family in a Protestant household '
#                                           'recounts her harrowing ordeal, '
#                                           'which culminated with a German '
#                                           'officer being billeted in the same '
#                                           'house. Reprint. 25,000 first '
#                                           'printing.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=99f1cOQJufMC&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=99f1cOQJufMC&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '0553381105',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9780553381108',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=99f1cOQJufMC&dq=isbn:9780553381108&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 238,
#                            'previewLink': 'http://books.google.com/books?id=99f1cOQJufMC&dq=isbn:9780553381108&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2001-01-01',
#                            'publisher': 'Random House of Canada',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': "Edith's Story"}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for The Flight Attendant (Television Tie-In Edition)
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=im6TEAAAQBAJ&hl=&source=gbs_api'},
#             'etag': '13f39bk26Ls',
#             'id': 'im6TEAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Look for Chris Bohjalian&#39;s new '
#                                           'novel, The Lioness!'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/im6TEAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Chris Bohjalian'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/The_Flight_Attendant_Television_Tie_In_E.html?hl=&id=im6TEAAAQBAJ',
#                            'categories': ['Fiction'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Now an acclaimed HBO Max series '
#                                           'starring Kaley Cuoco and Rosie '
#                                           'Perez, a powerful story about the '
#                                           'ways an entire life can change in '
#                                           'one night: a flight attendant wakes '
#                                           'up in the wrong hotel, in the wrong '
#                                           'bed, with a dead man—and no idea '
#                                           'what happened. Cassandra Bowden is '
#                                           'no stranger to hungover mornings. '
#                                           "She's a binge drinker, her job with "
#                                           'the airline making it easy to find '
#                                           'adventure, and the occasional '
#                                           'blackouts seem to be inevitable. '
#                                           'She lives with them—and the '
#                                           'accompanying self-loathing. When '
#                                           'she awakes in a Dubai hotel room, '
#                                           'she tries to piece the previous '
#                                           'night back together, counting the '
#                                           'minutes until she has to catch her '
#                                           'crew shuttle to the airport. She '
#                                           'quietly slides out of bed, careful '
#                                           'not to aggravate her already '
#                                           'pounding head, and looks at the man '
#                                           'she spent the night with. She sees '
#                                           'his dark hair. His utter stillness. '
#                                           'And blood, a slick, still wet pool '
#                                           'on the crisp white sheets. Afraid '
#                                           "to call the police—she's a single "
#                                           'woman alone in a hotel room far '
#                                           'from home—Cassie begins to lie. She '
#                                           'lies as she joins the other flight '
#                                           'attendants and pilots in the van. '
#                                           'She lies on the way to Paris as she '
#                                           'works the first class cabin. She '
#                                           'lies to the FBI agents in New York '
#                                           "who meet her at the gate. Soon it's "
#                                           'too late to come clean-or face the '
#                                           'truth about what really happened '
#                                           'back in Dubai. Could she have '
#                                           'killed him? If not, who did? Set '
#                                           'amid the captivating world of those '
#                                           'whose lives unfold at forty '
#                                           'thousand feet, The Flight Attendant '
#                                           'unveils a spellbinding story of '
#                                           'memory, of the giddy pleasures of '
#                                           'alcohol and the devastating '
#                                           'consequences of addiction, and of '
#                                           'murder far from home. Look for '
#                                           "Chris Bohjalian's new novel, The "
#                                           'Lioness!',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=im6TEAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=im6TEAAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780593314005',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '059331400X',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=im6TEAAAQBAJ&dq=isbn:9780593314005&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 0,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=im6TEAAAQBAJ&dq=isbn:9780593314005&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2020-12-08',
#                            'publisher': 'Vintage',
#                            'readingModes': {'image': False, 'text': True},
#                            'subtitle': 'A Novel',
#                            'title': 'The Flight Attendant (Television Tie-In '
#                                     'Edition)'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for The Dalai Lama's Cat
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=xn6PEAAAQBAJ&hl=&source=gbs_api'},
#             'etag': 'MNgdW8qQV18',
#             'id': 'xn6PEAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': '&quot;‘Oh!'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/xn6PEAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['David Michie'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/The_Dalai_Lama_s_Cat.html?hl=&id=xn6PEAAAQBAJ',
#                            'categories': ['Fiction'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': '"‘Oh! How adorable! I didn’t know '
#                                           'you had a cat!’ she exclaimed. I am '
#                                           'always surprised how many people '
#                                           'make this observation. Why should '
#                                           'His Holiness not have a cat?‘ If '
#                                           'only she could speak,’ continued '
#                                           'the actress. ‘I’m sure she’d have '
#                                           'such wisdom to share. ’And so the '
#                                           'seed was planted . . .I began to '
#                                           'think that perhaps the time had '
#                                           'come for me to write a book of my '
#                                           'own—a book that would convey some '
#                                           'of the wisdom I’ve learned sitting '
#                                           'not at the feet of the Dalai Lama '
#                                           'but even closer, on his lap. A book '
#                                           'that would tell my own tale . . . '
#                                           'how I was rescued from a fate too '
#                                           'grisly to contemplate to become the '
#                                           'constant companion of a man who is '
#                                           'not only one of the world’s '
#                                           'greatest spiritual leaders and a '
#                                           'Nobel Peace Prize Laureate but also '
#                                           'a dab hand with a can opener." '
#                                           'Starving and pitiful, a mud-smeared '
#                                           'kitten is rescued from the slums of '
#                                           'New Delhi and transported to a life '
#                                           'she could have never imagined. In a '
#                                           'beautiful sanctuary overlooking the '
#                                           'snow-capped Himalayas, she begins '
#                                           'her new life as the Dalai Lama’s '
#                                           'cat. Warmhearted, irreverent, and '
#                                           'wise, this cat of many names opens '
#                                           'a window to the inner sanctum of '
#                                           'life in Dharamsala. A tiny spy '
#                                           'observing the constant flow of '
#                                           'private meetings between His '
#                                           'Holiness and everyone from '
#                                           'Hollywood celebrities to '
#                                           'philanthropists to self-help '
#                                           'authors, the Dalai Lama’s cat '
#                                           'provides us with insights on how to '
#                                           'find happiness and meaning in a '
#                                           'busy, materialistic world. Her '
#                                           'story will put a smile on the face '
#                                           'of anyone who has been blessed by '
#                                           'the kneading paws and bountiful '
#                                           'purring of a cat.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=xn6PEAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=xn6PEAAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781401940584',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1401940587',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=xn6PEAAAQBAJ&dq=isbn:9781401940584&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 0,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=xn6PEAAAQBAJ&dq=isbn:9781401940584&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2012-10-01',
#                            'publisher': 'National Geographic Books',
#                            'readingModes': {'image': False, 'text': True},
#                            'title': "The Dalai Lama's Cat"}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for Joey Pigza Swallowed the Key (Joey Pigza Books)
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=ek8UymCf5IcC&hl=&source=gbs_api'},
#             'etag': '6aBG1wR4Kq0',
#             'id': 'ek8UymCf5IcC',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Joey Pigza can&#39;t sit still.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/ek8UymCf5IcC',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Jack Gantos'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Joey_Pigza_Swallowed_the_Key.html?hl=&id=ek8UymCf5IcC',
#                            'categories': ['Juvenile Fiction'],
#                            'contentVersion': '0.3.0.0.preview.0',
#                            'description': "Joey Pigza can't sit still. He "
#                                           "can't pay attention, he can't "
#                                           "follow the rules, and he can't help "
#                                           'it -- especially when his meds '
#                                           "aren't working. Joey's had problems "
#                                           'ever since he was born, problems '
#                                           'just like his dad and grandma have. '
#                                           "And whether he's wreaking havoc on "
#                                           'a class trip or swallowing his '
#                                           "house key, Joey's problems are "
#                                           'getting worse. In fact, his '
#                                           'behavior is so off the wall that '
#                                           'his teachers are threatening to '
#                                           'send him to the special-ed center '
#                                           "downtown. Joey knows he's really a "
#                                           'good kid, but no matter how hard he '
#                                           'tries to do the right thing, '
#                                           'something always seems to go wrong. '
#                                           'Will he ever get anything right?',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=ek8UymCf5IcC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=ek8UymCf5IcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780064408332',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '0064408337',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=ek8UymCf5IcC&dq=isbn:9780064408332&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 164,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=ek8UymCf5IcC&printsec=frontcover&dq=isbn:9780064408332&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2000',
#                            'publisher': 'Harper Collins',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'Joey Pigza Swallowed the Key'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for Are You There God?  It's Me, Margaret
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=Yb57Lnk8G6UC&hl=&source=gbs_api'},
#             'etag': 'OUdS5yACMpQ',
#             'id': 'Yb57Lnk8G6UC',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'A twelve-year-old talks to God '
#                                           'about her ardent desire to be grown '
#                                           'up.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/Yb57Lnk8G6UC',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Judy Blume'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Are_You_There_God_It_s_Me_Margaret.html?hl=&id=Yb57Lnk8G6UC',
#                            'categories': ['Juvenile Fiction'],
#                            'contentVersion': '1.3.0.0.preview.0',
#                            'description': 'A twelve-year-old talks to God '
#                                           'about her ardent desire to be grown '
#                                           'up.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Yb57Lnk8G6UC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=Yb57Lnk8G6UC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780440404194',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '0440404193',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=Yb57Lnk8G6UC&dq=isbn:9780440404194&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 162,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=Yb57Lnk8G6UC&printsec=frontcover&dq=isbn:9780440404194&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '1986',
#                            'publisher': 'Yearling',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': "Are You There God? It's Me, Margaret"}},
#            {'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=W4JnswEACAAJ&hl=&source=gbs_api'},
#             'etag': 'HiJ4o5oD7tk',
#             'id': 'W4JnswEACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Collects four novels by Judy Blume, '
#                                           'including &quot;Are You There God? '
#                                           'It&#39;s Me, Margaret, &quot;in '
#                                           'which a girl in the sixth grade '
#                                           'struggles with questions of '
#                                           'religion and identity as she enters '
#                                           'adolescence.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/W4JnswEACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Judy Blume'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Starring_Sally_J_Freedman_as_Herself.html?hl=&id=W4JnswEACAAJ',
#                            'categories': ['Girls'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Collects four novels by Judy Blume, '
#                                           'including "Are You There God? It\'s '
#                                           'Me, Margaret,"in which a girl in '
#                                           'the sixth grade struggles with '
#                                           'questions of religion and identity '
#                                           'as she enters adolescence.',
#                            'industryIdentifiers': [{'identifier': '0440404193',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9780440404194',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=W4JnswEACAAJ&dq=isbn:9780440404194&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=W4JnswEACAAJ&dq=isbn:9780440404194&hl=&cd=2&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '1986',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'Starring Sally J. Freedman as Herself'}}],
#  'kind': 'books#volumes',
#  'totalItems': 2}
# -- Getting info for Hannah Arendt: For Love of the World, Second Edition
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=WVaRUV7jOzUC&hl=&source=gbs_api'},
#             'etag': '6HbNeXS46Fg',
#             'id': 'WVaRUV7jOzUC',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'In a new preface the author offers '
#                                           'an account of writings by and about '
#                                           'Arendt that have appeared since the '
#                                           'book&#39;s 1982 publication, '
#                                           'providing a reassessment of her '
#                                           'subject&#39;s life and '
#                                           'achievement.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/WVaRUV7jOzUC',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Elisabeth Young-Bruehl'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Hannah_Arendt.html?hl=&id=WVaRUV7jOzUC',
#                            'categories': ['Biography & Autobiography'],
#                            'contentVersion': '0.4.4.0.preview.0',
#                            'description': 'This highly acclaimed, '
#                                           'prize-winning biography of one of '
#                                           'the foremost political philosophers '
#                                           'of the twentieth century is here '
#                                           'reissued in a trade paperback '
#                                           'edition for a new generation of '
#                                           'readers. In a new preface the '
#                                           'author offers an account of '
#                                           'writings by and about Arendt that '
#                                           "have appeared since the book's 1982 "
#                                           'publication, providing a '
#                                           "reassessment of her subject's life "
#                                           'and achievement. Praise for the '
#                                           'earlier edition: “Both a personal '
#                                           'and an intellectual biography . . . '
#                                           'It represents biography at its '
#                                           'best.”—Peter Berger, front page, '
#                                           'The New York Times Book Review “A '
#                                           'story of surprising drama . . . . '
#                                           'At last, we can see Arendt '
#                                           'whole.”—Jim Miller, Newsweek '
#                                           '“Indispensable to anyone interested '
#                                           'in the life, the thought, or . . . '
#                                           'the example of Hannah Arendt.”—Mark '
#                                           'Feeney, Boston Globe “An adventure '
#                                           'story that moves from pre-Nazi '
#                                           'Germany to fame in the United '
#                                           'States, and . . . a study of the '
#                                           'influences that shaped a sharp '
#                                           'political awareness.”—Richmond '
#                                           '(Va.) Times-Dispatch Cover drawing '
#                                           'by David Schorr',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=WVaRUV7jOzUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=WVaRUV7jOzUC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '0300105886',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9780300105889',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=WVaRUV7jOzUC&dq=isbn:9780300105889&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 638,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=WVaRUV7jOzUC&printsec=frontcover&dq=isbn:9780300105889&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2004-01-01',
#                            'publisher': 'Yale University Press',
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': 'For Love of the World',
#                            'title': 'Hannah Arendt'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for Heroes and Saints and Other Plays: Giving Up the Ghost, Shadow of a Man, Heroes and Saints
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=qxkgAQAAIAAJ&hl=&source=gbs_api'},
#             'etag': 'glvrv1Rw8D8',
#             'id': 'qxkgAQAAIAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Chicana playwright Cherrie '
#                                           'Moraga&#39;s premiere collection of '
#                                           'award winning theatre.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/qxkgAQAAIAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Cherríe Moraga'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Heroes_and_Saints_Other_Plays.html?hl=&id=qxkgAQAAIAAJ',
#                            'categories': ['Drama'],
#                            'contentVersion': '1.5.1.0.preview.0',
#                            'description': "Chicana playwright Cherrie Moraga's "
#                                           'premiere collection of award '
#                                           'winning theatre.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=qxkgAQAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=qxkgAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': 'STANFORD:36105016440419',
#                                                     'type': 'OTHER'}],
#                            'infoLink': 'http://books.google.com/books?id=qxkgAQAAIAAJ&dq=isbn:9780931122743&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 172,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=qxkgAQAAIAAJ&dq=isbn:9780931122743&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '1994',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'Heroes and Saints & Other Plays'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for Ceremony (Contemporary American Fiction Series)
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=MjCxAAAAIAAJ&hl=&source=gbs_api'},
#             'etag': 'DmrNS8gzo8A',
#             'id': 'MjCxAAAAIAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'One Navajo family, on a New Mexico '
#                                           'reservation, struggles to survive '
#                                           'in a world no longer theirs in the '
#                                           'years just before and after World '
#                                           'War II.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/MjCxAAAAIAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Leslie Marmon Silko'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Ceremony.html?hl=&id=MjCxAAAAIAAJ',
#                            'categories': ['Computers'],
#                            'contentVersion': '0.5.1.0.preview.0',
#                            'description': 'One Navajo family, on a New Mexico '
#                                           'reservation, struggles to survive '
#                                           'in a world no longer theirs in the '
#                                           'years just before and after World '
#                                           'War II.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=MjCxAAAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=MjCxAAAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': 'UCSC:32106014946187',
#                                                     'type': 'OTHER'}],
#                            'infoLink': 'http://books.google.com/books?id=MjCxAAAAIAAJ&dq=isbn:9780140086836&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 282,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=MjCxAAAAIAAJ&dq=isbn:9780140086836&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '1986',
#                            'publisher': 'New York, N.Y. : Penguin Books',
#                            'readingModes': {'image': False, 'text': False},
#                            'title': 'Ceremony'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}
# -- Getting info for And the Bridge Is Love
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=zHJrfIR-2GgC&hl=&source=gbs_api'},
#             'etag': 'fWRtoSLec0A',
#             'id': 'zHJrfIR-2GgC',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'The author of A Leak in the Heart: '
#                                           'Personal Essays presents a '
#                                           'collection of wise, wisecracking, '
#                                           'occasionally heartbreaking stories '
#                                           'of a Jewish childhood in '
#                                           'Depression-era Michigan.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/zHJrfIR-2GgC',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Faye Moskowitz'],
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/And_the_Bridge_Is_Love.html?hl=&id=zHJrfIR-2GgC',
#                            'categories': ['Biography & Autobiography'],
#                            'contentVersion': '1.8.2.0.preview.0',
#                            'description': 'The author of A Leak in the Heart: '
#                                           'Personal Essays presents a '
#                                           'collection of wise, wisecracking, '
#                                           'occasionally heartbreaking stories '
#                                           'of a Jewish childhood in '
#                                           'Depression-era Michigan. "A book '
#                                           'that will make you stand up and '
#                                           'cheer".--Detroit News.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=zHJrfIR-2GgC&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=zHJrfIR-2GgC&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '0807063274',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9780807063279',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=zHJrfIR-2GgC&dq=isbn:9780807063279&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 166,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=zHJrfIR-2GgC&dq=isbn:9780807063279&hl=&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '1993',
#                            'publisher': 'Beacon Press (MA)',
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': 'Life Stories',
#                            'title': 'And the Bridge Is Love'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}

# %%
df.head(10)
# Out:
#   item_type                                              title  \
# 0      book                                          Lifelines
# 1      book  Edith's Story: The True Story of a Young Girl'...
# 2      book   The Flight Attendant (Television Tie-In Edition)
# 3      book                               The Dalai Lama's Cat
# 4      book    Joey Pigza Swallowed the Key (Joey Pigza Books)
# 5      book              Are You There God?  It's Me, Margaret
# 6      book  Hannah Arendt: For Love of the World, Second E...
# 7      book  Heroes and Saints and Other Plays: Giving Up t...
# 8      book    Ceremony (Contemporary American Fiction Series)
# 9      book                             And the Bridge Is Love
#
#                  creators first_name     last_name     ean_isbn13  upc_isbn10  \
# 0               Leana Wen      Leana           Wen  9781250186232  1250186234
# 1           Edith Velmans      Edith       Velmans  9780553381108  0553381105
# 2         Chris Bohjalian      Chris     Bohjalian  9780593314005  059331400X
# 3            David Michie      David        Michie  9781401940584  1401940587
# 4             Jack Gantos       Jack        Gantos  9780064408332    64408337
# 5              Judy Blume       Judy         Blume  9780440404194   440404193
# 6  Elisabeth Young-Bruehl  Elisabeth  Young-Bruehl  9780300105889   300105886
# 7          Cherrie Moraga    Cherrie        Moraga  9780931122743   931122740
# 8     Leslie Marmon Silko     Leslie         Silko  9780140086836   140086838
# 9          Faye Moskowitz       Faye     Moskowitz  9780807063279   807063274
#
#                                          description  \
# 0  From medical expert Leana Wen, MD,Lifelines is...
# 1  In 1940, while the Germans occupied Holland, f...
# 2  Now a limited series on HBO Max starring Kaley...
# 3  Oh! How adorable! I didn&#039;t know you had a...
# 4  Joey Pigza can&#039;t sit still. He can&#039;t...
# 5  Are You There God? It&#039;s Me, Margaret No o...
# 6  This highly acclaimed, prize-winning biography...
# 7  Heroes and Saints &amp; Other Plays is Chicana...
# 8  Tayo, a young Native American, has been a pris...
# 9                                                NaN
#
#                           publisher publish_date  group tags  notes  price  \
# 0          Henry Holt &amp; Company   2021-07-27    NaN  NaN    NaN    NaN
# 1                            Bantam   2001-01-02    NaN  NaN    NaN    NaN
# 2  Knopf Doubleday Publishing Group   2020-12-08    NaN  NaN    NaN    NaN
# 3                 Hay House Visions   2012-10-01    NaN  NaN    NaN    NaN
# 4                     HarperCollins   2000-04-30    NaN  NaN    NaN    NaN
# 5                          Yearling   1972-01-01    NaN  NaN    NaN    NaN
# 6             Yale University Press   2004-10-11    NaN  NaN    NaN    NaN
# 7                    West End Press   1994-12-31    NaN  NaN    NaN    NaN
# 8                     Penguin Books   1986-03-04    NaN  NaN    NaN    NaN
# 9                      Beacon Press   1993-08-01    NaN  NaN    NaN    NaN
#
#    length  number_of_discs  number_of_players  age_group  ensemble  \
# 0   352.0              NaN                NaN        NaN       NaN
# 1   256.0              NaN                NaN        NaN       NaN
# 2   368.0              NaN                NaN        NaN       NaN
# 3   240.0              NaN                NaN        NaN       NaN
# 4   160.0              NaN                NaN        NaN       NaN
# 5   160.0              NaN                NaN        NaN       NaN
# 6   620.0              NaN                NaN        NaN       NaN
# 7   149.0              NaN                NaN        NaN       NaN
# 8   260.0              NaN                NaN        NaN       NaN
# 9   160.0              NaN                NaN        NaN       NaN
#
#    aspect_ratio  esrb  rating  review  review_date  status  began  completed  \
# 0           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 1           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 2           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 3           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 4           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 5           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 6           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 7           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 8           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 9           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
#
#         added  copies collection                 categories testing
# 0  2025-06-13       1    Norfolk             Social Science     NaN
# 1  2025-06-13       1    Norfolk  Biography & Autobiography     NaN
# 2  2025-06-13       1    Norfolk                    Fiction     NaN
# 3  2025-06-13       1      Maple                    Fiction     NaN
# 4  2025-06-13       1      Maple           Juvenile Fiction     NaN
# 5  2025-06-13       1      Maple           Juvenile Fiction     NaN
# 6  2025-06-13       1      Maple  Biography & Autobiography     NaN
# 7  2025-06-13       1      Maple                      Drama     NaN
# 8  2025-06-13       1      Maple                  Computers     NaN
# 9  2025-06-13       1      Maple  Biography & Autobiography     NaN
