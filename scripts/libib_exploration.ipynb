# %%
import pandas as pd
import glob
import os
import requests
import pprint

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
all_files = glob.glob(r'../data/*.csv')

# %%
# df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
all_data = []
for f in all_files:
    data = pd.read_csv(f)
    collection_name = os.path.splitext(os.path.basename(f))[0].capitalize()
    data['collection'] = collection_name
    all_data.append(data)

df = pd.concat(all_data, ignore_index = True)

# %%
df.head()
# Out:
#   item_type                                              title  \
# 0      book                                          Lifelines
# 1      book  Edith's Story: The True Story of a Young Girl'...
# 2      book   The Flight Attendant (Television Tie-In Edition)
# 3      book                               The Dalai Lama's Cat
# 4      book    Joey Pigza Swallowed the Key (Joey Pigza Books)
#
#           creators first_name  last_name     ean_isbn13  upc_isbn10  \
# 0        Leana Wen      Leana        Wen  9781250186232  1250186234
# 1    Edith Velmans      Edith    Velmans  9780553381108  0553381105
# 2  Chris Bohjalian      Chris  Bohjalian  9780593314005  059331400X
# 3     David Michie      David     Michie  9781401940584  1401940587
# 4      Jack Gantos       Jack     Gantos  9780064408332    64408337
#
#                                          description  \
# 0  From medical expert Leana Wen, MD,Lifelines is...
# 1  In 1940, while the Germans occupied Holland, f...
# 2  Now a limited series on HBO Max starring Kaley...
# 3  Oh! How adorable! I didn&#039;t know you had a...
# 4  Joey Pigza can&#039;t sit still. He can&#039;t...
#
#                           publisher publish_date  group tags  notes  price  \
# 0          Henry Holt &amp; Company   2021-07-27    NaN  NaN    NaN    NaN
# 1                            Bantam   2001-01-02    NaN  NaN    NaN    NaN
# 2  Knopf Doubleday Publishing Group   2020-12-08    NaN  NaN    NaN    NaN
# 3                 Hay House Visions   2012-10-01    NaN  NaN    NaN    NaN
# 4                     HarperCollins   2000-04-30    NaN  NaN    NaN    NaN
#
#    length  number_of_discs  number_of_players  age_group  ensemble  \
# 0   352.0              NaN                NaN        NaN       NaN
# 1   256.0              NaN                NaN        NaN       NaN
# 2   368.0              NaN                NaN        NaN       NaN
# 3   240.0              NaN                NaN        NaN       NaN
# 4   160.0              NaN                NaN        NaN       NaN
#
#    aspect_ratio  esrb  rating  review  review_date  status  began  completed  \
# 0           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 1           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 2           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 3           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
# 4           NaN   NaN     NaN     NaN          NaN     NaN    NaN        NaN
#
#         added  copies collection
# 0  2025-06-13       1    Norfolk
# 1  2025-06-13       1    Norfolk
# 2  2025-06-13       1    Norfolk
# 3  2025-06-13       1      Maple
# 4  2025-06-13       1      Maple

# %%
# Now loop through and call APIs for each entry
for index, row in df.tail(10).iterrows():
    
    print(f"-- Getting info for {row['title']}")
    book_isbn = row["ean_isbn13"]

    # Pull data from Open Library
    response = requests.get(f"https://openlibrary.org/isbn/{book_isbn}.json")
    pprint.pprint(response.text)

    # Pull data from Google Books API
    # response = requests.get(f"https://www.googleapis.com/books/v1/volumes?q=isbn:{book_isbn}")
    # pprint.pprint(response.text)
# Out:
# -- Getting info for Sammy Spider's First Passover
# ('{"publishers": ["Kar-Ben Copies", "Lerner Publishing Group"], "description": '
#  '{"type": "/type/text", "value": "A young spider makes a special contribution '
#  'to a family\'s Passover seder."}, "isbn_10": ["092937181X", "0929371828"], '
#  '"covers": [3886774, 709540], "lc_classifications": ["PZ7.R7622 San 1995", '
#  '"PZ7.R7622San 1995"], "key": "/books/OL1115826M", "authors": [{"key": '
#  '"/authors/OL33700A"}], "ocaid": "sammyspidersfirs0000rous_o1b7", '
#  '"publish_places": ["Rockville, MD"], "contributions": ["Kahn, Katherine, '
#  'ill."], "pagination": "1 v. (unpaged) :", "source_records": '
#  '["ia:sammyspidersfirs0000rous_o1b7", "bwb:9780929371825", '
#  '"bwb:9780929371818", '
#  '"marc:marc_loc_2016/BooksAll.2016.part23.utf8:148922763:828"], "title": '
#  '"Sammy Spider\'s first Passover", "dewey_decimal_class": ["[E]"], '
#  '"identifiers": {"goodreads": ["4764818", "848673"], "librarything": '
#  '["645363"]}, "languages": [{"key": "/languages/eng"}], "lccn": ["94041880"], '
#  '"subjects": ["Passover -- Fiction.", "Seder -- Fiction.", "Spiders -- '
#  'Fiction."], "publish_date": "1995", "publish_country": "mdu", '
#  '"by_statement": "Sylvia A. Rouss ; illustrated by Katherine Janus Kahn.", '
#  '"works": [{"key": "/works/OL507562W"}], "type": {"key": "/type/edition"}, '
#  '"latest_revision": 11, "revision": 11, "created": {"type": "/type/datetime", '
#  '"value": "2008-04-01T03:28:50.625462"}, "last_modified": {"type": '
#  '"/type/datetime", "value": "2023-02-17T02:00:07.810819"}}')
# -- Getting info for Sammy Spider's First Mitzvah (Kar-Ben Favorites)
# ('{"publishers": ["Lerner Publishing Group", "Kar-Ben Publishing \\u00ae"], '
#  '"source_records": ["bwb:9781467719483", "amazon:146771948X", '
#  '"promise:bwb_daily_pallets_2023-02-14:P8-CLO-626"], "title": "Sammy '
#  'Spider\'s First Mitzvah", "number_of_pages": 24, "isbn_13": '
#  '["9781467719483"], "languages": [{"key": "/languages/eng"}], "full_title": '
#  '"Sammy Spider\'s First Mitzvah", "lc_classifications": [""], "publish_date": '
#  '"2014", "key": "/books/OL28834927M", "authors": [{"key": '
#  '"/authors/OL33700A"}, {"key": "/authors/OL2941499A"}], "works": [{"key": '
#  '"/works/OL17869985W"}], "type": {"key": "/type/edition"}, "subjects": '
#  '["Children\'s fiction", "Spiders, fiction", "Sick, fiction", "Jews, united '
#  'states, fiction", "Conduct of life, fiction"], "local_id": '
#  '["urn:bwbsku:P8-CLO-626"], "latest_revision": 3, "revision": 3, "created": '
#  '{"type": "/type/datetime", "value": "2020-08-16T19:36:26.676031"}, '
#  '"last_modified": {"type": "/type/datetime", "value": '
#  '"2023-02-27T20:49:32.077642"}}')
# -- Getting info for The Starless Crown
# ('{"type": {"key": "/type/edition"}, "authors": [{"key": '
#  '"/authors/OL10755985A"}], "isbn_13": ["9781250334572"], "languages": '
#  '[{"key": "/languages/eng"}], "pagination": "720", "publish_date": "2023", '
#  '"publishers": ["Doherty Associates, LLC, Tom"], "source_records": '
#  '["bwb:9781250334572"], "title": "Starless Crown", "weight": "0.360", '
#  '"full_title": "Starless Crown", "works": [{"key": "/works/OL37625307W"}], '
#  '"key": "/books/OL50726451M", "latest_revision": 1, "revision": 1, "created": '
#  '{"type": "/type/datetime", "value": "2024-01-31T09:22:44.900434"}, '
#  '"last_modified": {"type": "/type/datetime", "value": '
#  '"2024-01-31T09:22:44.900434"}}')
# -- Getting info for In the Blood
# ('{"publishers": ["Simon & Schuster, Limited"], "last_modified": {"type": '
#  '"/type/datetime", "value": "2020-08-22T12:04:13.711503"}, "source_records": '
#  '["bwb:9781471111457"], "title": "In the Blood", "number_of_pages": 432, '
#  '"isbn_13": ["9781471111457"], "created": {"type": "/type/datetime", "value": '
#  '"2020-08-22T12:04:13.711503"}, "languages": [{"key": "/languages/eng"}], '
#  '"full_title": "In the Blood", "lc_classifications": ["PS3621.N486"], '
#  '"publish_date": "2014", "key": "/books/OL29137123M", "authors": [{"key": '
#  '"/authors/OL7170460A"}], "latest_revision": 1, "works": [{"key": '
#  '"/works/OL19356458W"}], "type": {"key": "/type/edition"}, "subjects": '
#  '["Fiction, suspense", "Fiction, thrillers, general"], "revision": 1}')
# -- Getting info for Impressions d'Afrique (French Edition)
# ('{"type": {"key": "/type/edition"}, "publish_date": "2005", '
#  '"publish_country": "fr", "languages": [{"key": "/languages/fre"}], "title": '
#  '"Impressions d\'Afrique", "by_statement": "Roussel ; pr\\u00e9sentation, '
#  'notes, dossier, chronologie, bibliographie par Tiphaine Samoyault", '
#  '"authors": [{"key": "/authors/OL473742A"}], "oclc_numbers": ["62735361"], '
#  '"series": ["Edition avec dossier", "Garnier Flammarion (Series)"], "notes": '
#  '{"type": "/type/text", "value": "Includes bibliographical references (p. '
#  '[371]-373)."}, "contributions": ["Samoyault, Tiphaine"], "publishers": '
#  '["Flammarion"], "publish_places": ["Paris"], "isbn_10": ["2080712322"], '
#  '"isbn_13": ["9782080712325"], "pagination": "373 p.", "number_of_pages": '
#  '373, "source_records": '
#  '["marc:harvard_bibliographic_metadata/ab.bib.10.20150123.full.mrc:614121080:799"], '
#  '"full_title": "Impressions d\'Afrique", "works": [{"key": '
#  '"/works/OL27277157W"}], "key": "/books/OL57186501M", "latest_revision": 1, '
#  '"revision": 1, "created": {"type": "/type/datetime", "value": '
#  '"2024-12-12T16:54:05.684006"}, "last_modified": {"type": "/type/datetime", '
#  '"value": "2024-12-12T16:54:05.684006"}}')
# -- Getting info for The Girl With the Dragon Tattoo
# ('{"notes": {"type": "/type/text", "value": "Source title: The Girl with the '
#  'Dragon Tattoo (Millennium Series)"}, "title": "The Girl with the Dragon '
#  'Tattoo (Millennium #1)", "authors": [{"key": "/authors/OL1414302A"}], '
#  '"publish_date": "June 23, 2009", "publishers": ["Vintage Crime/Black '
#  'Lizard"], "covers": [10544669], "physical_format": "Paperback", '
#  '"full_title": "The Girl with the Dragon Tattoo", "source_records": '
#  '["amazon:0307949486", "bwb:9780307454546", '
#  '"promise:bwb_daily_pallets_2020-04-09"], "type": {"key": "/type/edition"}, '
#  '"series": ["Millennium"], "isbn_13": ["9780307454546"], "isbn_10": '
#  '["0307454541"], "translated_from": [{"key": "/languages/swe"}], '
#  '"translation_of": "M\\u00e4n som hatar kvinnor", "languages": [{"key": '
#  '"/languages/eng"}], "copyright_date": "August 2005", "key": '
#  '"/books/OL28124656M", "number_of_pages": 672, "works": [{"key": '
#  '"/works/OL5784622W"}], "lc_classifications": ["PT9876.22.A6933M3613"], '
#  '"local_id": ["urn:bwbsku:823-BAA-613"], "identifiers": {"amazon": [""]}, '
#  '"latest_revision": 10, "revision": 10, "created": {"type": "/type/datetime", '
#  '"value": "2020-05-21T19:05:09.060716"}, "last_modified": {"type": '
#  '"/type/datetime", "value": "2022-12-10T12:35:35.889626"}}')
# -- Getting info for One Day in December: A Novel
# ('{"other_titles": ["1 day in December"], "subtitle": "a novel", '
#  '"description": {"type": "/type/text", "value": "Two people. Ten chances. One '
#  "unforgettable love story. Laurie is pretty sure love at first sight doesn't "
#  'exist anywhere but the movies. But then, through a misted-up bus window one '
#  'snowy December day, she sees a man who she knows instantly is the one. Their '
#  "eyes meet, there's a moment of pure magic...and then her bus drives away. "
#  "Certain they're fated to find each other again, Laurie spends a year "
#  "scanning every bus stop and cafe in London for him. But she doesn't find "
#  'him, not when it matters anyway. Instead they \\"reunite\\" at a Christmas '
#  'party, when her best friend Sarah giddily introduces her new boyfriend to '
#  "Laurie. It's Jack, the man from the bus. It would be. What follows for "
#  'Laurie, Sarah and Jack is ten years of friendship, heartbreak, missed '
#  'opportunities, roads not taken, and destinies reconsidered. One Day in '
#  'December is a joyous, heartwarming and immensely moving love story to escape '
#  'into and a reminder that fate takes inexplicable turns along the route to '
#  'happiness."}, "isbn_10": ["0525574689"], "lc_classifications": ["PR6119.I453 '
#  'O54 2018", "PR6119.I453O54 2018"], "key": "/books/OL26975567M", "authors": '
#  '[{"key": "/authors/OL7544010A"}], "subjects": ["Man-woman relationships", '
#  '"Interpersonal attraction", "Bus stops", "Best friends", "Fiction", '
#  '"Friendship", "Face"], "edition_name": "First edition.", "pagination": "409 '
#  'pages", "source_records": '
#  '["marc:marc_openlibraries_sanfranciscopubliclibrary/sfpl_chq_2018_12_24_run06.mrc:197955656:8197", '
#  '"bwb:9780525574682", "promise:bwb_daily_pallets_2021-05-14", '
#  '"promise:bwb_daily_pallets_2021-04-01"], "title": "One day in December", '
#  '"dewey_decimal_class": ["823/.92"], "notes": {"type": "/type/text", "value": '
#  '"Includes reader\'s extras."}, "number_of_pages": 409, "isbn_13": '
#  '["9780525574682"], "languages": [{"key": "/languages/eng"}], '
#  '"subject_places": ["London (England)"], "local_id": '
#  '["urn:sfpl:31223126514869", "urn:sfpl:31223134564898", '
#  '"urn:sfpl:31223134564906", "urn:sfpl:31223126514919", '
#  '"urn:sfpl:31223134564914", "urn:sfpl:31223134564922", '
#  '"urn:sfpl:31223134564930", "urn:sfpl:31223134564948", '
#  '"urn:sfpl:31223134564955", "urn:sfpl:31223134564963", '
#  '"urn:sfpl:31223126514810", "urn:sfpl:31223126514851", '
#  '"urn:sfpl:31223126514802", "urn:sfpl:31223134564971", '
#  '"urn:sfpl:31223134564989", "urn:sfpl:31223134564997", '
#  '"urn:sfpl:31223134565002", "urn:sfpl:31223134565010", '
#  '"urn:sfpl:31223134565028", "urn:sfpl:31223134565036", '
#  '"urn:sfpl:31223134565044", "urn:sfpl:31223134565051", '
#  '"urn:sfpl:31223134565069", "urn:sfpl:31223134565077", '
#  '"urn:sfpl:31223134565085", "urn:sfpl:31223134565093", '
#  '"urn:sfpl:31223134565101", "urn:sfpl:31223134565119", '
#  '"urn:sfpl:31223134565127", "urn:sfpl:31223134565135", '
#  '"urn:sfpl:31223134565143", "urn:sfpl:31223134565150", '
#  '"urn:sfpl:31223134565168", "urn:bwbsku:O7-BRN-379", '
#  '"urn:bwbsku:O7-BOI-067"], "publish_date": "2018", "publish_country": "nyu", '
#  '"by_statement": "Josie Silver", "oclc_numbers": ["1044621844"], "works": '
#  '[{"key": "/works/OL19762562W"}], "type": {"key": "/type/edition"}, "covers": '
#  '[12856531], "latest_revision": 5, "revision": 5, "created": {"type": '
#  '"/type/datetime", "value": "2019-05-31T09:05:50.305156"}, "last_modified": '
#  '{"type": "/type/datetime", "value": "2023-01-14T23:29:05.688641"}}')
# -- Getting info for Hope for the Autism Spectrum: A Mother and Son Journey of Insight and Biomedical Intervention
# ('{"publishers": ["Jessica Kingsley Publishers"], "languages": [{"key": '
#  '"/languages/eng"}], "subtitle": "a mother and son journey of insight and '
#  'biomedical intervention", "lc_classifications": ["RJ506.A9 K57 2010"], '
#  '"latest_revision": 2, "key": "/books/OL24490050M", "authors": [{"key": '
#  '"/authors/OL6591829A"}], "publish_places": ["London", "Philadelphia"], '
#  '"edition_name": "Pbk. ed.", "pagination": "p. cm.", "source_records": '
#  '["marc:marc_loc_updates/v38.i37.records.utf8:10014190:971"], "title": "Hope '
#  'for the autism spectrum", "lccn": ["2009048267"], "notes": {"type": '
#  '"/type/text", "value": "Includes bibliographical references and index."}, '
#  '"created": {"type": "/type/datetime", "value": '
#  '"2010-12-03T20:13:55.269595"}, "isbn_13": ["9781849058247"], '
#  '"dewey_decimal_class": ["618.92/85882"], "last_modified": {"type": '
#  '"/type/datetime", "value": "2011-04-28T06:05:06.617328"}, "publish_date": '
#  '"2010", "publish_country": "enk", "by_statement": "Sally Kirk ; foreword by '
#  'Elizabeth Mumper", "oclc_numbers": ["468233046"], "works": [{"key": '
#  '"/works/OL15532839W"}], "type": {"key": "/type/edition"}, "revision": 2}')
# -- Getting info for Into the Water: A Novel
# ('{"publishers": ["Penguin Publishing Group"], "subtitle": "A Novel", '
#  '"source_records": ["bwb:9780735211223", "amazon:0735211221", '
#  '"promise:bwb_daily_pallets_2020-07-23"], "title": "Into the Water", '
#  '"number_of_pages": 400, "isbn_13": ["9780735211223"], "languages": [{"key": '
#  '"/languages/eng"}], "full_title": "Into the Water A Novel", '
#  '"lc_classifications": [""], "publish_date": "2018", "key": '
#  '"/books/OL29791588M", "authors": [{"key": "/authors/OL2789840A"}], "works": '
#  '[{"key": "/works/OL17765039W"}], "type": {"key": "/type/edition"}, '
#  '"subjects": ["Fiction, psychological", "Fiction, thrillers, general"], '
#  '"local_id": ["urn:bwbsku:O6-DHX-568"], "latest_revision": 5, "revision": 5, '
#  '"created": {"type": "/type/datetime", "value": '
#  '"2020-08-31T06:45:17.124991"}, "last_modified": {"type": "/type/datetime", '
#  '"value": "2024-04-12T16:43:13.205027"}}')
# -- Getting info for ESL/EFL Teaching: Principles for Success
# ('{"publishers": ["Heinemann"], "number_of_pages": 292, "subtitle": '
#  '"principles for success", "isbn_10": ["0325000794"], "lc_classifications": '
#  '["P53"], "latest_revision": 4, "key": "/books/OL22493242M", "authors": '
#  '[{"key": "/authors/OL229194A"}], "publish_places": ["Portsmouth, NH"], '
#  '"contributions": ["Freeman, David E.", "Freeman, Yvonne S."], "pagination": '
#  '"xix, 292 p. :ill. ;", "title": "ESL-EFL teaching", "dewey_decimal_class": '
#  '["418/.007"], "notes": {"type": "/type/text", "value": "Rev. ed. of: Whole '
#  'language for second language learners. 1992.\\n\\nIncludes bibliographical '
#  'references (p. 277-288) and index."}, "identifiers": {"goodreads": '
#  '["851042"], "librarything": ["2029019"]}, "created": {"type": '
#  '"/type/datetime", "value": "2008-11-15T07:48:18.110155"}, "languages": '
#  '[{"key": "/languages/eng"}], "subjects": ["Language and languages -- Study '
#  'and teaching.", "Second language acquisition.", "English language -- Study '
#  'and teaching -- Foreign speakers."], "publish_date": "1998", '
#  '"publish_country": "xxu", "last_modified": {"type": "/type/datetime", '
#  '"value": "2010-08-19T05:39:45.101341"}, "by_statement": "Yvonne S. Freeman, '
#  'David E. Freeman.", "works": [{"key": "/works/OL1913438W"}], "type": {"key": '
#  '"/type/edition"}, "revision": 4}')
